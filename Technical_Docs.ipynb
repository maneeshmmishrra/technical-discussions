# %% [markdown]
# <a href="https://colab.research.google.com/github/maneeshmmishrra/technical-discussions/blob/main/Technical_Docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  return "Hi"
